# %%
def final(test_data):
  from keras.preprocessing.text import Tokenizer
  from keras.preprocessing.sequence import pad_sequences
  import pandas as pd
  import seaborn as sns
  import numpy as np
  import pickle
  from sklearn import preprocessing
  from sklearn.model_selection import RandomizedSearchCV
  from sklearn.metrics import log_loss
  from sklearn.metrics import confusion_matrix
  from sklearn.model_selection import train_test_split
  from gensim.scripts.glove2word2vec import glove2word2vec
  from keras.callbacks import EarlyStopping
  from keras.layers import Bidirectional,BatchNormalization,Flatten,Dropout,MaxPooling1D,Conv1D,Dense,LSTM,Dropout,multiply,Embedding,Concatenate,Input,Bidirectional,TimeDistributed
  from keras.preprocessing.text import Tokenizer 
  from keras.preprocessing.sequence import pad_sequences
  from keras.utils import np_utils
  from keras.models import Model
  from keras import backend as K 
  from datetime import datetime
  from tensorflow.keras.models import model_from_json
  import re
  def preprocess(sentence):
    sentence = sentence.lower()
    sentence = re.sub(r"\x92", "'",sentence)
    sentence = re.sub(r'[0-9\.]+', '',sentence)
    sentence = re.sub(r'\-',' ',sentence)
    sentence = re.sub(r' +', ' ',sentence)
    sentence = re.sub(r'[?!,.]','',sentence)
    sentence = re.sub(r"y'know",'you know',sentence)
    sentence = re.sub(r"\'t", " not", sentence)
    sentence = re.sub(r"\'re", " are", sentence)
    sentence = re.sub(r"\'s", " is", sentence)
    sentence = re.sub(r"\'d", " would", sentence)
    sentence = re.sub(r"\'ll", " will", sentence)
    sentence = re.sub(r"\'t", " not", sentence)
    sentence = re.sub(r"\'ve", " have", sentence)
    sentence = re.sub(r"\'m", " am", sentence)
    return sentence
  new_test=[]
  for i in (test_data.Utterance.values):
    new_test.append(preprocess(i))
  test_data['P_Utterance']=new_test
  X_test = test_data.P_Utterance
  with open('tokenizer.pickle', 'rb') as handle:
      b = pickle.load(handle)
  vocab_size = len(b.word_index) + 1 # for index zero we have to add +1  
  encoded_docs_test = b.texts_to_sequences(X_test)
  max_length = 50
  padded_docs_test = pad_sequences(encoded_docs_test, maxlen=max_length, padding='post')
  with open('meld_inputmatrix.pickle', 'rb') as handle:
    input_matrix = pickle.load(handle)
  with open('label_encoder.pickle', 'rb') as handle:
    prep = pickle.load(handle)   
  label_dict = dict(zip(prep.transform(prep.classes_), prep.classes_ ))
  sequence_input = Input(shape=(50,))
  embedding_layer = Embedding(vocab_size, 300,weights=[input_matrix],trainable=False)
  embedded_sequences = embedding_layer(sequence_input)
  x = Conv1D(256, 3, activation='relu')(embedded_sequences)
  x = Dropout(0.5)(x)
  x = BatchNormalization()(x) 
  x = LSTM(64, dropout=0.3, return_sequences=True)(x)
  x = Conv1D(128, 3, activation='relu')(x)
  x = Dropout(0.5)(x)
  x = BatchNormalization()(x) 
  x = Conv1D(64, 1, activation='relu')(x)
  x = Dropout(0.5)(x)
  x = BatchNormalization()(x)
  x = Flatten()(x)
  x = Dense(64, activation='relu')(x)
  preds = Dense(7, activation='softmax')(x)

  model1 = Model(sequence_input, preds)
  model1.load_weights("weights_email.h5")
  model1.compile(loss='categorical_crossentropy',
                optimizer='adam',
                )
  a = model1.predict(padded_docs_test).argmax(axis=-1)
  c=0
  for i in a:
    print('Test point ',c,' predicted_label ', label_dict[i])
    c=c+1

# %%
test_data = pd.read_csv('MELD-master/data/MELD/test_sent_emo.csv')
final(test_data)
# Out:
# Test point  0  predicted_label  neutral
# Test point  1  predicted_label  neutral
# Test point  2  predicted_label  neutral
# Test point  3  predicted_label  neutral
# Test point  4  predicted_label  neutral
# Test point  5  predicted_label  neutral
# Test point  6  predicted_label  neutral
# Test point  7  predicted_label  joy
# Test point  8  predicted_label  neutral
# Test point  9  predicted_label  neutral
# Test point  10  predicted_label  neutral
# Test point  11  predicted_label  neutral
# Test point  12  predicted_label  surprise
# Test point  13  predicted_label  neutral
# Test point  14  predicted_label  neutral
# Test point  15  predicted_label  neutral
# Test point  16  predicted_label  neutral
# Test point  17  predicted_label  neutral
# Test point  18  predicted_label  neutral
# Test point  19  predicted_label  neutral
# Test point  20  predicted_label  neutral
# Test point  21  predicted_label  joy
# Test point  22  predicted_label  neutral
# Test point  23  predicted_label  neutral
# Test point  24  predicted_label  neutral
# Test point  25  predicted_label  neutral
# Test point  26  predicted_label  neutral
# Test point  27  predicted_label  surprise
# Test point  28  predicted_label  neutral
# Test point  29  predicted_label  surprise
# Test point  30  predicted_label  surprise
# Test point  31  predicted_label  anger
# Test point  32  predicted_label  surprise
# Test point  33  predicted_label  anger
# Test point  34  predicted_label  surprise
# Test point  35  predicted_label  anger
# Test point  36  predicted_label  neutral
# Test point  37  predicted_label  neutral
# Test point  38  predicted_label  neutral
# Test point  39  predicted_label  neutral
# Test point  40  predicted_label  neutral
# Test point  41  predicted_label  neutral
# Test point  42  predicted_label  neutral
# Test point  43  predicted_label  neutral
# Test point  44  predicted_label  neutral
# Test point  45  predicted_label  neutral
# Test point  46  predicted_label  neutral
# Test point  47  predicted_label  neutral
# Test point  48  predicted_label  neutral
# Test point  49  predicted_label  neutral
# Test point  50  predicted_label  neutral
# Test point  51  predicted_label  neutral
# Test point  52  predicted_label  anger
# Test point  53  predicted_label  neutral
# Test point  54  predicted_label  neutral
# Test point  55  predicted_label  neutral
# Test point  56  predicted_label  neutral
# Test point  57  predicted_label  neutral
# Test point  58  predicted_label  neutral
# Test point  59  predicted_label  neutral
# Test point  60  predicted_label  joy
# Test point  61  predicted_label  neutral
# Test point  62  predicted_label  neutral
# Test point  63  predicted_label  neutral
# Test point  64  predicted_label  neutral
# Test point  65  predicted_label  neutral
# Test point  66  predicted_label  surprise
# Test point  67  predicted_label  neutral
# Test point  68  predicted_label  neutral
# Test point  69  predicted_label  neutral
# Test point  70  predicted_label  surprise
# Test point  71  predicted_label  neutral
# Test point  72  predicted_label  anger
# Test point  73  predicted_label  neutral
# Test point  74  predicted_label  surprise
# Test point  75  predicted_label  anger
# Test point  76  predicted_label  neutral
# Test point  77  predicted_label  anger
# Test point  78  predicted_label  neutral
# Test point  79  predicted_label  neutral
# Test point  80  predicted_label  neutral
# Test point  81  predicted_label  surprise
# Test point  82  predicted_label  neutral
# Test point  83  predicted_label  neutral
# Test point  84  predicted_label  neutral
# Test point  85  predicted_label  neutral
# Test point  86  predicted_label  neutral
# Test point  87  predicted_label  neutral
# Test point  88  predicted_label  neutral
# Test point  89  predicted_label  neutral
# Test point  90  predicted_label  neutral
# Test point  91  predicted_label  neutral
# Test point  92  predicted_label  neutral
# Test point  93  predicted_label  surprise
# Test point  94  predicted_label  neutral
# Test point  95  predicted_label  neutral
# Test point  96  predicted_label  neutral
# Test point  97  predicted_label  neutral
# Test point  98  predicted_label  neutral
# Test point  99  predicted_label  joy
# Test point  100  predicted_label  neutral
# Test point  101  predicted_label  neutral
# Test point  102  predicted_label  neutral
# Test point  103  predicted_label  neutral
# Test point  104  predicted_label  joy
# Test point  105  predicted_label  neutral
# Test point  106  predicted_label  neutral
# Test point  107  predicted_label  neutral
# Test point  108  predicted_label  neutral
# Test point  109  predicted_label  neutral
# Test point  110  predicted_label  neutral
# Test point  111  predicted_label  neutral
# Test point  112  predicted_label  neutral
# Test point  113  predicted_label  neutral
# Test point  114  predicted_label  neutral
# Test point  115  predicted_label  neutral
# Test point  116  predicted_label  joy
# Test point  117  predicted_label  neutral
# Test point  118  predicted_label  neutral
# Test point  119  predicted_label  surprise
# Test point  120  predicted_label  joy
# Test point  121  predicted_label  surprise
# Test point  122  predicted_label  neutral
# Test point  123  predicted_label  neutral
# Test point  124  predicted_label  neutral
# Test point  125  predicted_label  neutral
# Test point  126  predicted_label  neutral
# Test point  127  predicted_label  neutral
# Test point  128  predicted_label  joy
# Test point  129  predicted_label  neutral
# Test point  130  predicted_label  neutral
# Test point  131  predicted_label  neutral
# Test point  132  predicted_label  neutral
# Test point  133  predicted_label  neutral
# Test point  134  predicted_label  neutral
# Test point  135  predicted_label  neutral
# Test point  136  predicted_label  neutral
# Test point  137  predicted_label  anger
# Test point  138  predicted_label  neutral
# Test point  139  predicted_label  neutral
# Test point  140  predicted_label  neutral
# Test point  141  predicted_label  neutral
# Test point  142  predicted_label  neutral
# Test point  143  predicted_label  neutral
# Test point  144  predicted_label  neutral
# Test point  145  predicted_label  neutral
# Test point  146  predicted_label  neutral
# Test point  147  predicted_label  neutral
# Test point  148  predicted_label  neutral
# Test point  149  predicted_label  neutral
# Test point  150  predicted_label  neutral
# Test point  151  predicted_label  surprise
# Test point  152  predicted_label  neutral
# Test point  153  predicted_label  neutral
# Test point  154  predicted_label  neutral
# Test point  155  predicted_label  surprise
# Test point  156  predicted_label  neutral
# Test point  157  predicted_label  neutral
# Test point  158  predicted_label  neutral
# Test point  159  predicted_label  neutral
# Test point  160  predicted_label  neutral
# Test point  161  predicted_label  neutral
# Test point  162  predicted_label  neutral
# Test point  163  predicted_label  neutral
# Test point  164  predicted_label  anger
# Test point  165  predicted_label  neutral
# Test point  166  predicted_label  neutral
# Test point  167  predicted_label  neutral
# Test point  168  predicted_label  neutral
# Test point  169  predicted_label  neutral
# Test point  170  predicted_label  neutral
# Test point  171  predicted_label  neutral
# Test point  172  predicted_label  neutral
# Test point  173  predicted_label  neutral
# Test point  174  predicted_label  neutral
# Test point  175  predicted_label  surprise
# Test point  176  predicted_label  neutral
# Test point  177  predicted_label  neutral
# Test point  178  predicted_label  neutral
# Test point  179  predicted_label  neutral
# Test point  180  predicted_label  neutral
# Test point  181  predicted_label  neutral
# Test point  182  predicted_label  neutral
# Test point  183  predicted_label  neutral
# Test point  184  predicted_label  neutral
# Test point  185  predicted_label  neutral
# Test point  186  predicted_label  surprise
# Test point  187  predicted_label  anger
# Test point  188  predicted_label  neutral
# Test point  189  predicted_label  neutral
# Test point  190  predicted_label  neutral
# Test point  191  predicted_label  neutral
# Test point  192  predicted_label  neutral
# Test point  193  predicted_label  neutral
# Test point  194  predicted_label  neutral
# Test point  195  predicted_label  neutral
# Test point  196  predicted_label  neutral
# Test point  197  predicted_label  neutral
# Test point  198  predicted_label  joy
# Test point  199  predicted_label  neutral
# Test point  200  predicted_label  neutral
# Test point  201  predicted_label  neutral
# Test point  202  predicted_label  anger
# Test point  203  predicted_label  neutral
# Test point  204  predicted_label  neutral
# Test point  205  predicted_label  surprise
# Test point  206  predicted_label  neutral
# Test point  207  predicted_label  neutral
# Test point  208  predicted_label  neutral
# Test point  209  predicted_label  anger
# Test point  210  predicted_label  neutral
# Test point  211  predicted_label  neutral
# Test point  212  predicted_label  joy
# Test point  213  predicted_label  neutral
# Test point  214  predicted_label  neutral
# Test point  215  predicted_label  neutral
# Test point  216  predicted_label  neutral
# Test point  217  predicted_label  joy
# Test point  218  predicted_label  neutral
# Test point  219  predicted_label  neutral
# Test point  220  predicted_label  neutral
# Test point  221  predicted_label  neutral
# Test point  222  predicted_label  neutral
# Test point  223  predicted_label  neutral
# Test point  224  predicted_label  neutral
# Test point  225  predicted_label  neutral
# Test point  226  predicted_label  neutral
# Test point  227  predicted_label  neutral
# Test point  228  predicted_label  neutral
# Test point  229  predicted_label  neutral
# Test point  230  predicted_label  neutral
# Test point  231  predicted_label  sadness
# Test point  232  predicted_label  neutral
# Test point  233  predicted_label  surprise
# Test point  234  predicted_label  surprise
# Test point  235  predicted_label  neutral
# Test point  236  predicted_label  neutral
# Test point  237  predicted_label  neutral
# Test point  238  predicted_label  surprise
# Test point  239  predicted_label  neutral
# Test point  240  predicted_label  neutral
# Test point  241  predicted_label  anger
# Test point  242  predicted_label  neutral
# Test point  243  predicted_label  surprise
# Test point  244  predicted_label  neutral
# Test point  245  predicted_label  joy
# Test point  246  predicted_label  neutral
# Test point  247  predicted_label  neutral
# Test point  248  predicted_label  neutral
# Test point  249  predicted_label  neutral
# Test point  250  predicted_label  neutral
# Test point  251  predicted_label  neutral
# Test point  252  predicted_label  neutral
# Test point  253  predicted_label  neutral
# Test point  254  predicted_label  neutral
# Test point  255  predicted_label  anger
# Test point  256  predicted_label  neutral
# Test point  257  predicted_label  neutral
# Test point  258  predicted_label  anger
# Test point  259  predicted_label  neutral
# Test point  260  predicted_label  neutral
# Test point  261  predicted_label  neutral
# Test point  262  predicted_label  neutral
# Test point  263  predicted_label  neutral
# Test point  264  predicted_label  neutral
# Test point  265  predicted_label  neutral
# Test point  266  predicted_label  surprise
# Test point  267  predicted_label  surprise
# Test point  268  predicted_label  neutral
# Test point  269  predicted_label  surprise
# Test point  270  predicted_label  surprise
# Test point  271  predicted_label  neutral
# Test point  272  predicted_label  neutral
# Test point  273  predicted_label  neutral
# Test point  274  predicted_label  neutral
# Test point  275  predicted_label  neutral
# Test point  276  predicted_label  neutral
# Test point  277  predicted_label  neutral
# Test point  278  predicted_label  surprise
# Test point  279  predicted_label  surprise
# Test point  280  predicted_label  surprise
# Test point  281  predicted_label  joy
# Test point  282  predicted_label  neutral
# Test point  283  predicted_label  neutral
# Test point  284  predicted_label  neutral
# Test point  285  predicted_label  surprise
# Test point  286  predicted_label  neutral
# Test point  287  predicted_label  neutral
# Test point  288  predicted_label  joy
# Test point  289  predicted_label  neutral
# Test point  290  predicted_label  neutral
# Test point  291  predicted_label  neutral
# Test point  292  predicted_label  neutral
# Test point  293  predicted_label  neutral
# Test point  294  predicted_label  surprise
# Test point  295  predicted_label  sadness
# Test point  296  predicted_label  anger
# Test point  297  predicted_label  neutral
# Test point  298  predicted_label  joy
# Test point  299  predicted_label  neutral
# Test point  300  predicted_label  neutral
# Test point  301  predicted_label  neutral
# Test point  302  predicted_label  neutral
# Test point  303  predicted_label  neutral
# Test point  304  predicted_label  anger
# Test point  305  predicted_label  sadness
# Test point  306  predicted_label  neutral
# Test point  307  predicted_label  neutral
# Test point  308  predicted_label  surprise
# Test point  309  predicted_label  neutral
# Test point  310  predicted_label  neutral
# Test point  311  predicted_label  neutral
# Test point  312  predicted_label  neutral
# Test point  313  predicted_label  neutral
# Test point  314  predicted_label  neutral
# Test point  315  predicted_label  surprise
# Test point  316  predicted_label  neutral
# Test point  317  predicted_label  neutral
# Test point  318  predicted_label  neutral
# Test point  319  predicted_label  joy
# Test point  320  predicted_label  neutral
# Test point  321  predicted_label  neutral
# Test point  322  predicted_label  surprise
# Test point  323  predicted_label  neutral
# Test point  324  predicted_label  neutral
# Test point  325  predicted_label  neutral
# Test point  326  predicted_label  neutral
# Test point  327  predicted_label  neutral
# Test point  328  predicted_label  surprise
# Test point  329  predicted_label  neutral
# Test point  330  predicted_label  neutral
# Test point  331  predicted_label  neutral
# Test point  332  predicted_label  neutral
# Test point  333  predicted_label  neutral
# Test point  334  predicted_label  joy
# Test point  335  predicted_label  neutral
# Test point  336  predicted_label  sadness
# Test point  337  predicted_label  neutral
# Test point  338  predicted_label  neutral
# Test point  339  predicted_label  neutral
# Test point  340  predicted_label  neutral
# Test point  341  predicted_label  neutral
# Test point  342  predicted_label  neutral
# Test point  343  predicted_label  neutral
# Test point  344  predicted_label  neutral
# Test point  345  predicted_label  joy
# Test point  346  predicted_label  neutral
# Test point  347  predicted_label  neutral
# Test point  348  predicted_label  joy
# Test point  349  predicted_label  neutral
# Test point  350  predicted_label  surprise
# Test point  351  predicted_label  neutral
# Test point  352  predicted_label  surprise
# Test point  353  predicted_label  joy
# Test point  354  predicted_label  neutral
# Test point  355  predicted_label  joy
# Test point  356  predicted_label  neutral
# Test point  357  predicted_label  joy
# Test point  358  predicted_label  surprise
# Test point  359  predicted_label  neutral
# Test point  360  predicted_label  joy
# Test point  361  predicted_label  joy
# Test point  362  predicted_label  joy
# Test point  363  predicted_label  neutral
# Test point  364  predicted_label  joy
# Test point  365  predicted_label  surprise
# Test point  366  predicted_label  neutral
# Test point  367  predicted_label  neutral
# Test point  368  predicted_label  neutral
# Test point  369  predicted_label  neutral
# Test point  370  predicted_label  neutral
# Test point  371  predicted_label  neutral
# Test point  372  predicted_label  anger
# Test point  373  predicted_label  neutral
# Test point  374  predicted_label  joy
# Test point  375  predicted_label  neutral
# Test point  376  predicted_label  joy
# Test point  377  predicted_label  neutral
# Test point  378  predicted_label  neutral
# Test point  379  predicted_label  neutral
# Test point  380  predicted_label  neutral
# Test point  381  predicted_label  surprise
# Test point  382  predicted_label  neutral
# Test point  383  predicted_label  neutral
# Test point  384  predicted_label  joy
# Test point  385  predicted_label  neutral
# Test point  386  predicted_label  neutral
# Test point  387  predicted_label  neutral
# Test point  388  predicted_label  neutral
# Test point  389  predicted_label  neutral
# Test point  390  predicted_label  neutral
# Test point  391  predicted_label  neutral
# Test point  392  predicted_label  neutral
# Test point  393  predicted_label  neutral
# Test point  394  predicted_label  neutral
# Test point  395  predicted_label  neutral
# Test point  396  predicted_label  neutral
# Test point  397  predicted_label  joy
# Test point  398  predicted_label  neutral
# Test point  399  predicted_label  surprise
# Test point  400  predicted_label  joy
# Test point  401  predicted_label  neutral
# Test point  402  predicted_label  neutral
# Test point  403  predicted_label  neutral
# Test point  404  predicted_label  neutral
# Test point  405  predicted_label  joy
# Test point  406  predicted_label  neutral
# Test point  407  predicted_label  neutral
# Test point  408  predicted_label  surprise
# Test point  409  predicted_label  neutral
# Test point  410  predicted_label  joy
# Test point  411  predicted_label  neutral
# Test point  412  predicted_label  neutral
# Test point  413  predicted_label  joy
# Test point  414  predicted_label  anger
# Test point  415  predicted_label  neutral
# Test point  416  predicted_label  neutral
# Test point  417  predicted_label  neutral
# Test point  418  predicted_label  neutral
# Test point  419  predicted_label  neutral
# Test point  420  predicted_label  neutral
# Test point  421  predicted_label  neutral
# Test point  422  predicted_label  neutral
# Test point  423  predicted_label  neutral
# Test point  424  predicted_label  neutral
# Test point  425  predicted_label  neutral
# Test point  426  predicted_label  neutral
# Test point  427  predicted_label  neutral
# Test point  428  predicted_label  neutral
# Test point  429  predicted_label  neutral
# Test point  430  predicted_label  neutral
# Test point  431  predicted_label  neutral
# Test point  432  predicted_label  joy
# Test point  433  predicted_label  joy
# Test point  434  predicted_label  joy
# Test point  435  predicted_label  neutral
# Test point  436  predicted_label  neutral
# Test point  437  predicted_label  neutral
# Test point  438  predicted_label  neutral
# Test point  439  predicted_label  neutral
# Test point  440  predicted_label  neutral
# Test point  441  predicted_label  neutral
# Test point  442  predicted_label  neutral
# Test point  443  predicted_label  neutral
# Test point  444  predicted_label  neutral
# Test point  445  predicted_label  neutral
# Test point  446  predicted_label  neutral
# Test point  447  predicted_label  neutral
# Test point  448  predicted_label  neutral
# Test point  449  predicted_label  neutral
# Test point  450  predicted_label  neutral
# Test point  451  predicted_label  neutral
# Test point  452  predicted_label  neutral
# Test point  453  predicted_label  surprise
# Test point  454  predicted_label  neutral
# Test point  455  predicted_label  neutral
# Test point  456  predicted_label  neutral
# Test point  457  predicted_label  neutral
# Test point  458  predicted_label  neutral
# Test point  459  predicted_label  neutral
# Test point  460  predicted_label  neutral
# Test point  461  predicted_label  neutral
# Test point  462  predicted_label  neutral
# Test point  463  predicted_label  neutral
# Test point  464  predicted_label  neutral
# Test point  465  predicted_label  neutral
# Test point  466  predicted_label  neutral
# Test point  467  predicted_label  neutral
# Test point  468  predicted_label  neutral
# Test point  469  predicted_label  neutral
# Test point  470  predicted_label  anger
# Test point  471  predicted_label  neutral
# Test point  472  predicted_label  neutral
# Test point  473  predicted_label  surprise
# Test point  474  predicted_label  joy
# Test point  475  predicted_label  joy
# Test point  476  predicted_label  neutral
# Test point  477  predicted_label  neutral
# Test point  478  predicted_label  surprise
# Test point  479  predicted_label  neutral
# Test point  480  predicted_label  neutral
# Test point  481  predicted_label  neutral
# Test point  482  predicted_label  neutral
# Test point  483  predicted_label  joy
# Test point  484  predicted_label  neutral
# Test point  485  predicted_label  neutral
# Test point  486  predicted_label  neutral
# Test point  487  predicted_label  neutral
# Test point  488  predicted_label  neutral
# Test point  489  predicted_label  surprise
# Test point  490  predicted_label  neutral
# Test point  491  predicted_label  neutral
# Test point  492  predicted_label  neutral
# Test point  493  predicted_label  neutral
# Test point  494  predicted_label  sadness
# Test point  495  predicted_label  neutral
# Test point  496  predicted_label  neutral
# Test point  497  predicted_label  neutral
# Test point  498  predicted_label  neutral
# Test point  499  predicted_label  sadness
# Test point  500  predicted_label  neutral
# Test point  501  predicted_label  joy
# Test point  502  predicted_label  surprise
# Test point  503  predicted_label  neutral
# Test point  504  predicted_label  neutral
# Test point  505  predicted_label  neutral
# Test point  506  predicted_label  neutral
# Test point  507  predicted_label  joy
# Test point  508  predicted_label  neutral
# Test point  509  predicted_label  surprise
# Test point  510  predicted_label  joy
# Test point  511  predicted_label  neutral
# Test point  512  predicted_label  neutral
# Test point  513  predicted_label  neutral
# Test point  514  predicted_label  neutral
# Test point  515  predicted_label  joy
# Test point  516  predicted_label  neutral
# Test point  517  predicted_label  neutral
# Test point  518  predicted_label  neutral
# Test point  519  predicted_label  surprise
# Test point  520  predicted_label  joy
# Test point  521  predicted_label  neutral
# Test point  522  predicted_label  neutral
# Test point  523  predicted_label  neutral
# Test point  524  predicted_label  neutral
# Test point  525  predicted_label  neutral
# Test point  526  predicted_label  neutral
# Test point  527  predicted_label  neutral
# Test point  528  predicted_label  neutral
# Test point  529  predicted_label  joy
# Test point  530  predicted_label  joy
# Test point  531  predicted_label  neutral
# Test point  532  predicted_label  neutral
# Test point  533  predicted_label  neutral
# Test point  534  predicted_label  neutral
# Test point  535  predicted_label  neutral
# Test point  536  predicted_label  sadness
# Test point  537  predicted_label  neutral
# Test point  538  predicted_label  neutral
# Test point  539  predicted_label  joy
# Test point  540  predicted_label  surprise
# Test point  541  predicted_label  neutral
# Test point  542  predicted_label  neutral
# Test point  543  predicted_label  neutral
# Test point  544  predicted_label  neutral
# Test point  545  predicted_label  neutral
# Test point  546  predicted_label  neutral
# Test point  547  predicted_label  neutral
# Test point  548  predicted_label  neutral
# Test point  549  predicted_label  neutral
# Test point  550  predicted_label  neutral
# Test point  551  predicted_label  surprise
# Test point  552  predicted_label  neutral
# Test point  553  predicted_label  neutral
# Test point  554  predicted_label  surprise
# Test point  555  predicted_label  neutral
# Test point  556  predicted_label  neutral
# Test point  557  predicted_label  neutral
# Test point  558  predicted_label  neutral
# Test point  559  predicted_label  neutral
# Test point  560  predicted_label  neutral
# Test point  561  predicted_label  neutral
# Test point  562  predicted_label  neutral
# Test point  563  predicted_label  neutral
# Test point  564  predicted_label  neutral
# Test point  565  predicted_label  surprise
# Test point  566  predicted_label  neutral
# Test point  567  predicted_label  neutral
# Test point  568  predicted_label  neutral
# Test point  569  predicted_label  neutral
# Test point  570  predicted_label  neutral
# Test point  571  predicted_label  neutral
# Test point  572  predicted_label  neutral
# Test point  573  predicted_label  neutral
# Test point  574  predicted_label  neutral
# Test point  575  predicted_label  neutral
# Test point  576  predicted_label  neutral
# Test point  577  predicted_label  neutral
# Test point  578  predicted_label  neutral
# Test point  579  predicted_label  joy
# Test point  580  predicted_label  joy
# Test point  581  predicted_label  joy
# Test point  582  predicted_label  joy
# Test point  583  predicted_label  joy
# Test point  584  predicted_label  neutral
# Test point  585  predicted_label  neutral
# Test point  586  predicted_label  neutral
# Test point  587  predicted_label  neutral
# Test point  588  predicted_label  neutral
# Test point  589  predicted_label  neutral
# Test point  590  predicted_label  neutral
# Test point  591  predicted_label  surprise
# Test point  592  predicted_label  joy
# Test point  593  predicted_label  neutral
# Test point  594  predicted_label  neutral
# Test point  595  predicted_label  neutral
# Test point  596  predicted_label  neutral
# Test point  597  predicted_label  joy
# Test point  598  predicted_label  neutral
# Test point  599  predicted_label  neutral
# Test point  600  predicted_label  neutral
# Test point  601  predicted_label  surprise
# Test point  602  predicted_label  neutral
# Test point  603  predicted_label  neutral
# Test point  604  predicted_label  neutral
# Test point  605  predicted_label  neutral
# Test point  606  predicted_label  neutral
# Test point  607  predicted_label  neutral
# Test point  608  predicted_label  neutral
# Test point  609  predicted_label  neutral
# Test point  610  predicted_label  neutral
# Test point  611  predicted_label  neutral
# Test point  612  predicted_label  neutral
# Test point  613  predicted_label  neutral
# Test point  614  predicted_label  neutral
# Test point  615  predicted_label  neutral
# Test point  616  predicted_label  neutral
# Test point  617  predicted_label  neutral
# Test point  618  predicted_label  surprise
# Test point  619  predicted_label  neutral
# Test point  620  predicted_label  neutral
# Test point  621  predicted_label  neutral
# Test point  622  predicted_label  surprise
# Test point  623  predicted_label  neutral
# Test point  624  predicted_label  neutral
# Test point  625  predicted_label  joy
# Test point  626  predicted_label  neutral
# Test point  627  predicted_label  neutral
# Test point  628  predicted_label  neutral
# Test point  629  predicted_label  joy
# Test point  630  predicted_label  neutral
# Test point  631  predicted_label  neutral
# Test point  632  predicted_label  neutral
# Test point  633  predicted_label  neutral
# Test point  634  predicted_label  neutral
# Test point  635  predicted_label  joy
# Test point  636  predicted_label  neutral
# Test point  637  predicted_label  neutral
# Test point  638  predicted_label  neutral
# Test point  639  predicted_label  neutral
# Test point  640  predicted_label  neutral
# Test point  641  predicted_label  neutral
# Test point  642  predicted_label  neutral
# Test point  643  predicted_label  neutral
# Test point  644  predicted_label  neutral
# Test point  645  predicted_label  neutral
# Test point  646  predicted_label  neutral
# Test point  647  predicted_label  neutral
# Test point  648  predicted_label  neutral
# Test point  649  predicted_label  neutral
# Test point  650  predicted_label  neutral
# Test point  651  predicted_label  neutral
# Test point  652  predicted_label  neutral
# Test point  653  predicted_label  neutral
# Test point  654  predicted_label  neutral
# Test point  655  predicted_label  neutral
# Test point  656  predicted_label  neutral
# Test point  657  predicted_label  neutral
# Test point  658  predicted_label  neutral
# Test point  659  predicted_label  neutral
# Test point  660  predicted_label  neutral
# Test point  661  predicted_label  neutral
# Test point  662  predicted_label  neutral
# Test point  663  predicted_label  neutral
# Test point  664  predicted_label  neutral
# Test point  665  predicted_label  neutral
# Test point  666  predicted_label  neutral
# Test point  667  predicted_label  neutral
# Test point  668  predicted_label  neutral
# Test point  669  predicted_label  neutral
# Test point  670  predicted_label  joy
# Test point  671  predicted_label  neutral
# Test point  672  predicted_label  neutral
# Test point  673  predicted_label  neutral
# Test point  674  predicted_label  neutral
# Test point  675  predicted_label  neutral
# Test point  676  predicted_label  neutral
# Test point  677  predicted_label  neutral
# Test point  678  predicted_label  surprise
# Test point  679  predicted_label  neutral
# Test point  680  predicted_label  neutral
# Test point  681  predicted_label  neutral
# Test point  682  predicted_label  neutral
# Test point  683  predicted_label  neutral
# Test point  684  predicted_label  neutral
# Test point  685  predicted_label  joy
# Test point  686  predicted_label  neutral
# Test point  687  predicted_label  neutral
# Test point  688  predicted_label  neutral
# Test point  689  predicted_label  neutral
# Test point  690  predicted_label  neutral
# Test point  691  predicted_label  neutral
# Test point  692  predicted_label  neutral
# Test point  693  predicted_label  surprise
# Test point  694  predicted_label  neutral
# Test point  695  predicted_label  neutral
# Test point  696  predicted_label  neutral
# Test point  697  predicted_label  neutral
# Test point  698  predicted_label  joy
# Test point  699  predicted_label  neutral
# Test point  700  predicted_label  neutral
# Test point  701  predicted_label  neutral
# Test point  702  predicted_label  neutral
# Test point  703  predicted_label  joy
# Test point  704  predicted_label  neutral
# Test point  705  predicted_label  anger
# Test point  706  predicted_label  neutral
# Test point  707  predicted_label  neutral
# Test point  708  predicted_label  neutral
# Test point  709  predicted_label  surprise
# Test point  710  predicted_label  neutral
# Test point  711  predicted_label  neutral
# Test point  712  predicted_label  neutral
# Test point  713  predicted_label  neutral
# Test point  714  predicted_label  neutral
# Test point  715  predicted_label  neutral
# Test point  716  predicted_label  neutral
# Test point  717  predicted_label  neutral
# Test point  718  predicted_label  joy
# Test point  719  predicted_label  neutral
# Test point  720  predicted_label  neutral
# Test point  721  predicted_label  surprise
# Test point  722  predicted_label  neutral
# Test point  723  predicted_label  neutral
# Test point  724  predicted_label  neutral
# Test point  725  predicted_label  neutral
# Test point  726  predicted_label  neutral
# Test point  727  predicted_label  neutral
# Test point  728  predicted_label  neutral
# Test point  729  predicted_label  neutral
# Test point  730  predicted_label  neutral
# Test point  731  predicted_label  neutral
# Test point  732  predicted_label  neutral
# Test point  733  predicted_label  neutral
# Test point  734  predicted_label  neutral
# Test point  735  predicted_label  neutral
# Test point  736  predicted_label  neutral
# Test point  737  predicted_label  neutral
# Test point  738  predicted_label  neutral
# Test point  739  predicted_label  neutral
# Test point  740  predicted_label  surprise
# Test point  741  predicted_label  surprise
# Test point  742  predicted_label  neutral
# Test point  743  predicted_label  neutral
# Test point  744  predicted_label  surprise
# Test point  745  predicted_label  surprise
# Test point  746  predicted_label  neutral
# Test point  747  predicted_label  neutral
# Test point  748  predicted_label  neutral
# Test point  749  predicted_label  surprise
# Test point  750  predicted_label  neutral
# Test point  751  predicted_label  neutral
# Test point  752  predicted_label  neutral
# Test point  753  predicted_label  neutral
# Test point  754  predicted_label  surprise
# Test point  755  predicted_label  neutral
# Test point  756  predicted_label  neutral
# Test point  757  predicted_label  neutral
# Test point  758  predicted_label  neutral
# Test point  759  predicted_label  neutral
# Test point  760  predicted_label  joy
# Test point  761  predicted_label  anger
# Test point  762  predicted_label  joy
# Test point  763  predicted_label  neutral
# Test point  764  predicted_label  joy
# Test point  765  predicted_label  surprise
# Test point  766  predicted_label  neutral
# Test point  767  predicted_label  neutral
# Test point  768  predicted_label  neutral
# Test point  769  predicted_label  neutral
# Test point  770  predicted_label  neutral
# Test point  771  predicted_label  neutral
# Test point  772  predicted_label  neutral
# Test point  773  predicted_label  anger
# Test point  774  predicted_label  neutral
# Test point  775  predicted_label  neutral
# Test point  776  predicted_label  neutral
# Test point  777  predicted_label  neutral
# Test point  778  predicted_label  neutral
# Test point  779  predicted_label  neutral
# Test point  780  predicted_label  neutral
# Test point  781  predicted_label  neutral
# Test point  782  predicted_label  surprise
# Test point  783  predicted_label  neutral
# Test point  784  predicted_label  neutral
# Test point  785  predicted_label  neutral
# Test point  786  predicted_label  neutral
# Test point  787  predicted_label  neutral
# Test point  788  predicted_label  neutral
# Test point  789  predicted_label  neutral
# Test point  790  predicted_label  neutral
# Test point  791  predicted_label  neutral
# Test point  792  predicted_label  neutral
# Test point  793  predicted_label  neutral
# Test point  794  predicted_label  anger
# Test point  795  predicted_label  neutral
# Test point  796  predicted_label  neutral
# Test point  797  predicted_label  neutral
# Test point  798  predicted_label  neutral
# Test point  799  predicted_label  neutral
# Test point  800  predicted_label  neutral
# Test point  801  predicted_label  neutral
# Test point  802  predicted_label  neutral
# Test point  803  predicted_label  neutral
# Test point  804  predicted_label  surprise
# Test point  805  predicted_label  neutral
# Test point  806  predicted_label  neutral
# Test point  807  predicted_label  surprise
# Test point  808  predicted_label  joy
# Test point  809  predicted_label  neutral
# Test point  810  predicted_label  surprise
# Test point  811  predicted_label  joy
# Test point  812  predicted_label  neutral
# Test point  813  predicted_label  neutral
# Test point  814  predicted_label  surprise
# Test point  815  predicted_label  neutral
# Test point  816  predicted_label  neutral
# Test point  817  predicted_label  neutral
# Test point  818  predicted_label  joy
# Test point  819  predicted_label  neutral
# Test point  820  predicted_label  neutral
# Test point  821  predicted_label  neutral
# Test point  822  predicted_label  neutral
# Test point  823  predicted_label  neutral
# Test point  824  predicted_label  joy
# Test point  825  predicted_label  neutral
# Test point  826  predicted_label  neutral
# Test point  827  predicted_label  neutral
# Test point  828  predicted_label  neutral
# Test point  829  predicted_label  neutral
# Test point  830  predicted_label  neutral
# Test point  831  predicted_label  neutral
# Test point  832  predicted_label  neutral
# Test point  833  predicted_label  surprise
# Test point  834  predicted_label  neutral
# Test point  835  predicted_label  neutral
# Test point  836  predicted_label  neutral
# Test point  837  predicted_label  neutral
# Test point  838  predicted_label  neutral
# Test point  839  predicted_label  neutral
# Test point  840  predicted_label  neutral
# Test point  841  predicted_label  neutral
# Test point  842  predicted_label  joy
# Test point  843  predicted_label  neutral
# Test point  844  predicted_label  neutral
# Test point  845  predicted_label  neutral
# Test point  846  predicted_label  neutral
# Test point  847  predicted_label  neutral
# Test point  848  predicted_label  neutral
# Test point  849  predicted_label  neutral
# Test point  850  predicted_label  neutral
# Test point  851  predicted_label  neutral
# Test point  852  predicted_label  joy
# Test point  853  predicted_label  neutral
# Test point  854  predicted_label  surprise
# Test point  855  predicted_label  neutral
# Test point  856  predicted_label  neutral
# Test point  857  predicted_label  neutral
# Test point  858  predicted_label  neutral
# Test point  859  predicted_label  anger
# Test point  860  predicted_label  neutral
# Test point  861  predicted_label  neutral
# Test point  862  predicted_label  joy
# Test point  863  predicted_label  joy
# Test point  864  predicted_label  neutral
# Test point  865  predicted_label  surprise
# Test point  866  predicted_label  neutral
# Test point  867  predicted_label  surprise
# Test point  868  predicted_label  neutral
# Test point  869  predicted_label  joy
# Test point  870  predicted_label  neutral
# Test point  871  predicted_label  neutral
# Test point  872  predicted_label  neutral
# Test point  873  predicted_label  neutral
# Test point  874  predicted_label  neutral
# Test point  875  predicted_label  neutral
# Test point  876  predicted_label  neutral
# Test point  877  predicted_label  neutral
# Test point  878  predicted_label  neutral
# Test point  879  predicted_label  neutral
# Test point  880  predicted_label  neutral
# Test point  881  predicted_label  neutral
# Test point  882  predicted_label  neutral
# Test point  883  predicted_label  neutral
# Test point  884  predicted_label  anger
# Test point  885  predicted_label  neutral
# Test point  886  predicted_label  neutral
# Test point  887  predicted_label  neutral
# Test point  888  predicted_label  neutral
# Test point  889  predicted_label  neutral
# Test point  890  predicted_label  neutral
# Test point  891  predicted_label  anger
# Test point  892  predicted_label  neutral
# Test point  893  predicted_label  neutral
# Test point  894  predicted_label  neutral
# Test point  895  predicted_label  neutral
# Test point  896  predicted_label  neutral
# Test point  897  predicted_label  neutral
# Test point  898  predicted_label  joy
# Test point  899  predicted_label  surprise
# Test point  900  predicted_label  neutral
# Test point  901  predicted_label  neutral
# Test point  902  predicted_label  neutral
# Test point  903  predicted_label  neutral
# Test point  904  predicted_label  neutral
# Test point  905  predicted_label  neutral
# Test point  906  predicted_label  neutral
# Test point  907  predicted_label  neutral
# Test point  908  predicted_label  neutral
# Test point  909  predicted_label  neutral
# Test point  910  predicted_label  neutral
# Test point  911  predicted_label  surprise
# Test point  912  predicted_label  neutral
# Test point  913  predicted_label  joy
# Test point  914  predicted_label  neutral
# Test point  915  predicted_label  neutral
# Test point  916  predicted_label  neutral
# Test point  917  predicted_label  neutral
# Test point  918  predicted_label  neutral
# Test point  919  predicted_label  neutral
# Test point  920  predicted_label  neutral
# Test point  921  predicted_label  neutral
# Test point  922  predicted_label  neutral
# Test point  923  predicted_label  neutral
# Test point  924  predicted_label  surprise
# Test point  925  predicted_label  neutral
# Test point  926  predicted_label  neutral
# Test point  927  predicted_label  neutral
# Test point  928  predicted_label  anger
# Test point  929  predicted_label  neutral
# Test point  930  predicted_label  neutral
# Test point  931  predicted_label  neutral
# Test point  932  predicted_label  neutral
# Test point  933  predicted_label  surprise
# Test point  934  predicted_label  neutral
# Test point  935  predicted_label  neutral
# Test point  936  predicted_label  neutral
# Test point  937  predicted_label  neutral
# Test point  938  predicted_label  neutral
# Test point  939  predicted_label  neutral
# Test point  940  predicted_label  neutral
# Test point  941  predicted_label  surprise
# Test point  942  predicted_label  neutral
# Test point  943  predicted_label  neutral
# Test point  944  predicted_label  surprise
# Test point  945  predicted_label  neutral
# Test point  946  predicted_label  neutral
# Test point  947  predicted_label  neutral
# Test point  948  predicted_label  anger
# Test point  949  predicted_label  neutral
# Test point  950  predicted_label  neutral
# Test point  951  predicted_label  neutral
# Test point  952  predicted_label  anger
# Test point  953  predicted_label  joy
# Test point  954  predicted_label  surprise
# Test point  955  predicted_label  neutral
# Test point  956  predicted_label  neutral
# Test point  957  predicted_label  neutral
# Test point  958  predicted_label  neutral
# Test point  959  predicted_label  neutral
# Test point  960  predicted_label  neutral
# Test point  961  predicted_label  neutral
# Test point  962  predicted_label  neutral
# Test point  963  predicted_label  surprise
# Test point  964  predicted_label  surprise
# Test point  965  predicted_label  neutral
# Test point  966  predicted_label  neutral
# Test point  967  predicted_label  neutral
# Test point  968  predicted_label  neutral
# Test point  969  predicted_label  neutral
# Test point  970  predicted_label  neutral
# Test point  971  predicted_label  neutral
# Test point  972  predicted_label  neutral
# Test point  973  predicted_label  neutral
# Test point  974  predicted_label  neutral
# Test point  975  predicted_label  joy
# Test point  976  predicted_label  neutral
# Test point  977  predicted_label  sadness
# Test point  978  predicted_label  anger
# Test point  979  predicted_label  anger
# Test point  980  predicted_label  neutral
# Test point  981  predicted_label  neutral
# Test point  982  predicted_label  neutral
# Test point  983  predicted_label  neutral
# Test point  984  predicted_label  joy
# Test point  985  predicted_label  neutral
# Test point  986  predicted_label  anger
# Test point  987  predicted_label  neutral
# Test point  988  predicted_label  neutral
# Test point  989  predicted_label  neutral
# Test point  990  predicted_label  neutral
# Test point  991  predicted_label  neutral
# Test point  992  predicted_label  surprise
# Test point  993  predicted_label  neutral
# Test point  994  predicted_label  neutral
# Test point  995  predicted_label  neutral
# Test point  996  predicted_label  neutral
# Test point  997  predicted_label  neutral
# Test point  998  predicted_label  surprise
# Test point  999  predicted_label  surprise
# Test point  1000  predicted_label  surprise
# Test point  1001  predicted_label  surprise
# Test point  1002  predicted_label  joy
# Test point  1003  predicted_label  neutral
# Test point  1004  predicted_label  neutral
# Test point  1005  predicted_label  neutral
# Test point  1006  predicted_label  neutral
# Test point  1007  predicted_label  neutral
# Test point  1008  predicted_label  neutral
# Test point  1009  predicted_label  neutral
# Test point  1010  predicted_label  joy
# Test point  1011  predicted_label  neutral
# Test point  1012  predicted_label  joy
# Test point  1013  predicted_label  neutral
# Test point  1014  predicted_label  neutral
# Test point  1015  predicted_label  surprise
# Test point  1016  predicted_label  neutral
# Test point  1017  predicted_label  neutral
# Test point  1018  predicted_label  neutral
# Test point  1019  predicted_label  neutral
# Test point  1020  predicted_label  joy
# Test point  1021  predicted_label  neutral
# Test point  1022  predicted_label  anger
# Test point  1023  predicted_label  surprise
# Test point  1024  predicted_label  joy
# Test point  1025  predicted_label  neutral
# Test point  1026  predicted_label  neutral
# Test point  1027  predicted_label  neutral
# Test point  1028  predicted_label  neutral
# Test point  1029  predicted_label  surprise
# Test point  1030  predicted_label  sadness
# Test point  1031  predicted_label  neutral
# Test point  1032  predicted_label  neutral
# Test point  1033  predicted_label  neutral
# Test point  1034  predicted_label  neutral
# Test point  1035  predicted_label  neutral
# Test point  1036  predicted_label  neutral
# Test point  1037  predicted_label  neutral
# Test point  1038  predicted_label  neutral
# Test point  1039  predicted_label  neutral
# Test point  1040  predicted_label  neutral
# Test point  1041  predicted_label  joy
# Test point  1042  predicted_label  neutral
# Test point  1043  predicted_label  neutral
# Test point  1044  predicted_label  neutral
# Test point  1045  predicted_label  neutral
# Test point  1046  predicted_label  neutral
# Test point  1047  predicted_label  neutral
# Test point  1048  predicted_label  neutral
# Test point  1049  predicted_label  neutral
# Test point  1050  predicted_label  neutral
# Test point  1051  predicted_label  neutral
# Test point  1052  predicted_label  joy
# Test point  1053  predicted_label  joy
# Test point  1054  predicted_label  neutral
# Test point  1055  predicted_label  neutral
# Test point  1056  predicted_label  neutral
# Test point  1057  predicted_label  neutral
# Test point  1058  predicted_label  neutral
# Test point  1059  predicted_label  neutral
# Test point  1060  predicted_label  neutral
# Test point  1061  predicted_label  neutral
# Test point  1062  predicted_label  neutral
# Test point  1063  predicted_label  neutral
# Test point  1064  predicted_label  neutral
# Test point  1065  predicted_label  neutral
# Test point  1066  predicted_label  neutral
# Test point  1067  predicted_label  neutral
# Test point  1068  predicted_label  neutral
# Test point  1069  predicted_label  neutral
# Test point  1070  predicted_label  neutral
# Test point  1071  predicted_label  neutral
# Test point  1072  predicted_label  neutral
# Test point  1073  predicted_label  neutral
# Test point  1074  predicted_label  neutral
# Test point  1075  predicted_label  joy
# Test point  1076  predicted_label  neutral
# Test point  1077  predicted_label  neutral
# Test point  1078  predicted_label  neutral
# Test point  1079  predicted_label  neutral
# Test point  1080  predicted_label  neutral
# Test point  1081  predicted_label  neutral
# Test point  1082  predicted_label  neutral
# Test point  1083  predicted_label  neutral
# Test point  1084  predicted_label  neutral
# Test point  1085  predicted_label  neutral
# Test point  1086  predicted_label  neutral
# Test point  1087  predicted_label  neutral
# Test point  1088  predicted_label  neutral
# Test point  1089  predicted_label  neutral
# Test point  1090  predicted_label  neutral
# Test point  1091  predicted_label  neutral
# Test point  1092  predicted_label  neutral
# Test point  1093  predicted_label  neutral
# Test point  1094  predicted_label  neutral
# Test point  1095  predicted_label  neutral
# Test point  1096  predicted_label  neutral
# Test point  1097  predicted_label  neutral
# Test point  1098  predicted_label  joy
# Test point  1099  predicted_label  neutral
# Test point  1100  predicted_label  neutral
# Test point  1101  predicted_label  neutral
# Test point  1102  predicted_label  joy
# Test point  1103  predicted_label  joy
# Test point  1104  predicted_label  neutral
# Test point  1105  predicted_label  surprise
# Test point  1106  predicted_label  neutral
# Test point  1107  predicted_label  joy
# Test point  1108  predicted_label  neutral
# Test point  1109  predicted_label  neutral
# Test point  1110  predicted_label  neutral
# Test point  1111  predicted_label  neutral
# Test point  1112  predicted_label  neutral
# Test point  1113  predicted_label  neutral
# Test point  1114  predicted_label  neutral
# Test point  1115  predicted_label  neutral
# Test point  1116  predicted_label  neutral
# Test point  1117  predicted_label  neutral
# Test point  1118  predicted_label  neutral
# Test point  1119  predicted_label  neutral
# Test point  1120  predicted_label  surprise
# Test point  1121  predicted_label  neutral
# Test point  1122  predicted_label  surprise
# Test point  1123  predicted_label  neutral
# Test point  1124  predicted_label  neutral
# Test point  1125  predicted_label  neutral
# Test point  1126  predicted_label  neutral
# Test point  1127  predicted_label  surprise
# Test point  1128  predicted_label  neutral
# Test point  1129  predicted_label  neutral
# Test point  1130  predicted_label  joy
# Test point  1131  predicted_label  neutral
# Test point  1132  predicted_label  neutral
# Test point  1133  predicted_label  neutral
# Test point  1134  predicted_label  surprise
# Test point  1135  predicted_label  neutral
# Test point  1136  predicted_label  neutral
# Test point  1137  predicted_label  neutral
# Test point  1138  predicted_label  neutral
# Test point  1139  predicted_label  neutral
# Test point  1140  predicted_label  neutral
# Test point  1141  predicted_label  neutral
# Test point  1142  predicted_label  neutral
# Test point  1143  predicted_label  neutral
# Test point  1144  predicted_label  neutral
# Test point  1145  predicted_label  neutral
# Test point  1146  predicted_label  neutral
# Test point  1147  predicted_label  joy
# Test point  1148  predicted_label  neutral
# Test point  1149  predicted_label  neutral
# ...
# Test point  2236  predicted_label  neutral
# Test point  2237  predicted_label  neutral
# Test point  2238  predicted_label  neutral
# Test point  2239  predicted_label  surprise
# Test point  2240  predicted_label  neutral
# Test point  2241  predicted_label  neutral
# Test point  2242  predicted_label  neutral
# Test point  2243  predicted_label  neutral
# Test point  2244  predicted_label  neutral
# Test point  2245  predicted_label  neutral
# Test point  2246  predicted_label  neutral
# Test point  2247  predicted_label  neutral
# Test point  2248  predicted_label  neutral
# Test point  2249  predicted_label  neutral
# Test point  2250  predicted_label  neutral
# Test point  2251  predicted_label  neutral
# Test point  2252  predicted_label  surprise
# Test point  2253  predicted_label  neutral
# Test point  2254  predicted_label  surprise
# Test point  2255  predicted_label  neutral
# Test point  2256  predicted_label  neutral
# Test point  2257  predicted_label  neutral
# Test point  2258  predicted_label  neutral
# Test point  2259  predicted_label  surprise
# Test point  2260  predicted_label  neutral
# Test point  2261  predicted_label  neutral
# Test point  2262  predicted_label  surprise
# Test point  2263  predicted_label  neutral
# Test point  2264  predicted_label  neutral
# Test point  2265  predicted_label  neutral
# Test point  2266  predicted_label  neutral
# Test point  2267  predicted_label  neutral
# Test point  2268  predicted_label  joy
# Test point  2269  predicted_label  neutral
# Test point  2270  predicted_label  neutral
# Test point  2271  predicted_label  neutral
# Test point  2272  predicted_label  neutral
# Test point  2273  predicted_label  neutral
# Test point  2274  predicted_label  neutral
# Test point  2275  predicted_label  neutral
# Test point  2276  predicted_label  joy
# Test point  2277  predicted_label  neutral
# Test point  2278  predicted_label  neutral
# Test point  2279  predicted_label  joy
# Test point  2280  predicted_label  neutral
# Test point  2281  predicted_label  neutral
# Test point  2282  predicted_label  neutral
# Test point  2283  predicted_label  surprise
# Test point  2284  predicted_label  neutral
# Test point  2285  predicted_label  neutral
# Test point  2286  predicted_label  neutral
# Test point  2287  predicted_label  surprise
# Test point  2288  predicted_label  joy
# Test point  2289  predicted_label  neutral
# Test point  2290  predicted_label  neutral
# Test point  2291  predicted_label  surprise
# Test point  2292  predicted_label  neutral
# Test point  2293  predicted_label  neutral
# Test point  2294  predicted_label  neutral
# Test point  2295  predicted_label  surprise
# Test point  2296  predicted_label  neutral
# Test point  2297  predicted_label  neutral
# Test point  2298  predicted_label  neutral
# Test point  2299  predicted_label  neutral
# Test point  2300  predicted_label  anger
# Test point  2301  predicted_label  neutral
# Test point  2302  predicted_label  neutral
# Test point  2303  predicted_label  neutral
# Test point  2304  predicted_label  neutral
# Test point  2305  predicted_label  neutral
# Test point  2306  predicted_label  neutral
# Test point  2307  predicted_label  neutral
# Test point  2308  predicted_label  neutral
# Test point  2309  predicted_label  neutral
# Test point  2310  predicted_label  joy
# Test point  2311  predicted_label  joy
# Test point  2312  predicted_label  neutral
# Test point  2313  predicted_label  neutral
# Test point  2314  predicted_label  neutral
# Test point  2315  predicted_label  neutral
# Test point  2316  predicted_label  neutral
# Test point  2317  predicted_label  neutral
# Test point  2318  predicted_label  neutral
# Test point  2319  predicted_label  neutral
# Test point  2320  predicted_label  neutral
# Test point  2321  predicted_label  neutral
# Test point  2322  predicted_label  surprise
# Test point  2323  predicted_label  joy
# Test point  2324  predicted_label  joy
# Test point  2325  predicted_label  joy
# Test point  2326  predicted_label  neutral
# Test point  2327  predicted_label  joy
# Test point  2328  predicted_label  neutral
# Test point  2329  predicted_label  neutral
# Test point  2330  predicted_label  joy
# Test point  2331  predicted_label  anger
# Test point  2332  predicted_label  neutral
# Test point  2333  predicted_label  neutral
# Test point  2334  predicted_label  neutral
# Test point  2335  predicted_label  surprise
# Test point  2336  predicted_label  neutral
# Test point  2337  predicted_label  neutral
# Test point  2338  predicted_label  neutral
# Test point  2339  predicted_label  neutral
# Test point  2340  predicted_label  surprise
# Test point  2341  predicted_label  neutral
# Test point  2342  predicted_label  neutral
# Test point  2343  predicted_label  neutral
# Test point  2344  predicted_label  neutral
# Test point  2345  predicted_label  neutral
# Test point  2346  predicted_label  neutral
# Test point  2347  predicted_label  neutral
# Test point  2348  predicted_label  neutral
# Test point  2349  predicted_label  neutral
# Test point  2350  predicted_label  neutral
# Test point  2351  predicted_label  neutral
# Test point  2352  predicted_label  neutral
# Test point  2353  predicted_label  neutral
# Test point  2354  predicted_label  neutral
# Test point  2355  predicted_label  neutral
# Test point  2356  predicted_label  neutral
# Test point  2357  predicted_label  surprise
# Test point  2358  predicted_label  neutral
# Test point  2359  predicted_label  neutral
# Test point  2360  predicted_label  neutral
# Test point  2361  predicted_label  neutral
# Test point  2362  predicted_label  neutral
# Test point  2363  predicted_label  surprise
# Test point  2364  predicted_label  neutral
# Test point  2365  predicted_label  surprise
# Test point  2366  predicted_label  anger
# Test point  2367  predicted_label  neutral
# Test point  2368  predicted_label  neutral
# Test point  2369  predicted_label  neutral
# Test point  2370  predicted_label  neutral
# Test point  2371  predicted_label  neutral
# Test point  2372  predicted_label  neutral
# Test point  2373  predicted_label  neutral
# Test point  2374  predicted_label  neutral
# Test point  2375  predicted_label  surprise
# Test point  2376  predicted_label  neutral
# Test point  2377  predicted_label  neutral
# Test point  2378  predicted_label  neutral
# Test point  2379  predicted_label  surprise
# Test point  2380  predicted_label  neutral
# Test point  2381  predicted_label  neutral
# Test point  2382  predicted_label  joy
# Test point  2383  predicted_label  neutral
# Test point  2384  predicted_label  joy
# Test point  2385  predicted_label  neutral
# Test point  2386  predicted_label  joy
# Test point  2387  predicted_label  neutral
# Test point  2388  predicted_label  neutral
# Test point  2389  predicted_label  neutral
# Test point  2390  predicted_label  neutral
# Test point  2391  predicted_label  neutral
# Test point  2392  predicted_label  joy
# Test point  2393  predicted_label  anger
# Test point  2394  predicted_label  neutral
# Test point  2395  predicted_label  surprise
# Test point  2396  predicted_label  neutral
# Test point  2397  predicted_label  neutral
# Test point  2398  predicted_label  joy
# Test point  2399  predicted_label  neutral
# Test point  2400  predicted_label  neutral
# Test point  2401  predicted_label  neutral
# Test point  2402  predicted_label  neutral
# Test point  2403  predicted_label  neutral
# Test point  2404  predicted_label  joy
# Test point  2405  predicted_label  neutral
# Test point  2406  predicted_label  neutral
# Test point  2407  predicted_label  neutral
# Test point  2408  predicted_label  neutral
# Test point  2409  predicted_label  neutral
# Test point  2410  predicted_label  neutral
# Test point  2411  predicted_label  neutral
# Test point  2412  predicted_label  neutral
# Test point  2413  predicted_label  neutral
# Test point  2414  predicted_label  neutral
# Test point  2415  predicted_label  joy
# Test point  2416  predicted_label  neutral
# Test point  2417  predicted_label  neutral
# Test point  2418  predicted_label  neutral
# Test point  2419  predicted_label  anger
# Test point  2420  predicted_label  neutral
# Test point  2421  predicted_label  neutral
# Test point  2422  predicted_label  neutral
# Test point  2423  predicted_label  surprise
# Test point  2424  predicted_label  neutral
# Test point  2425  predicted_label  neutral
# Test point  2426  predicted_label  neutral
# Test point  2427  predicted_label  neutral
# Test point  2428  predicted_label  neutral
# Test point  2429  predicted_label  neutral
# Test point  2430  predicted_label  anger
# Test point  2431  predicted_label  neutral
# Test point  2432  predicted_label  anger
# Test point  2433  predicted_label  neutral
# Test point  2434  predicted_label  neutral
# Test point  2435  predicted_label  joy
# Test point  2436  predicted_label  neutral
# Test point  2437  predicted_label  neutral
# Test point  2438  predicted_label  joy
# Test point  2439  predicted_label  anger
# Test point  2440  predicted_label  neutral
# Test point  2441  predicted_label  surprise
# Test point  2442  predicted_label  neutral
# Test point  2443  predicted_label  neutral
# Test point  2444  predicted_label  neutral
# Test point  2445  predicted_label  neutral
# Test point  2446  predicted_label  surprise
# Test point  2447  predicted_label  neutral
# Test point  2448  predicted_label  joy
# Test point  2449  predicted_label  neutral
# Test point  2450  predicted_label  neutral
# Test point  2451  predicted_label  neutral
# Test point  2452  predicted_label  neutral
# Test point  2453  predicted_label  neutral
# Test point  2454  predicted_label  neutral
# Test point  2455  predicted_label  neutral
# Test point  2456  predicted_label  joy
# Test point  2457  predicted_label  surprise
# Test point  2458  predicted_label  surprise
# Test point  2459  predicted_label  neutral
# Test point  2460  predicted_label  neutral
# Test point  2461  predicted_label  neutral
# Test point  2462  predicted_label  neutral
# Test point  2463  predicted_label  neutral
# Test point  2464  predicted_label  joy
# Test point  2465  predicted_label  neutral
# Test point  2466  predicted_label  neutral
# Test point  2467  predicted_label  neutral
# Test point  2468  predicted_label  neutral
# Test point  2469  predicted_label  neutral
# Test point  2470  predicted_label  neutral
# Test point  2471  predicted_label  surprise
# Test point  2472  predicted_label  neutral
# Test point  2473  predicted_label  neutral
# Test point  2474  predicted_label  neutral
# Test point  2475  predicted_label  neutral
# Test point  2476  predicted_label  neutral
# Test point  2477  predicted_label  neutral
# Test point  2478  predicted_label  neutral
# Test point  2479  predicted_label  neutral
# Test point  2480  predicted_label  neutral
# Test point  2481  predicted_label  neutral
# Test point  2482  predicted_label  anger
# Test point  2483  predicted_label  neutral
# Test point  2484  predicted_label  surprise
# Test point  2485  predicted_label  neutral
# Test point  2486  predicted_label  neutral
# Test point  2487  predicted_label  joy
# Test point  2488  predicted_label  neutral
# Test point  2489  predicted_label  neutral
# Test point  2490  predicted_label  neutral
# Test point  2491  predicted_label  neutral
# Test point  2492  predicted_label  neutral
# Test point  2493  predicted_label  neutral
# Test point  2494  predicted_label  neutral
# Test point  2495  predicted_label  neutral
# Test point  2496  predicted_label  neutral
# Test point  2497  predicted_label  neutral
# Test point  2498  predicted_label  joy
# Test point  2499  predicted_label  anger
# Test point  2500  predicted_label  neutral
# Test point  2501  predicted_label  surprise
# Test point  2502  predicted_label  neutral
# Test point  2503  predicted_label  surprise
# Test point  2504  predicted_label  neutral
# Test point  2505  predicted_label  neutral
# Test point  2506  predicted_label  neutral
# Test point  2507  predicted_label  neutral
# Test point  2508  predicted_label  neutral
# Test point  2509  predicted_label  neutral
# Test point  2510  predicted_label  surprise
# Test point  2511  predicted_label  joy
# Test point  2512  predicted_label  neutral
# Test point  2513  predicted_label  neutral
# Test point  2514  predicted_label  joy
# Test point  2515  predicted_label  neutral
# Test point  2516  predicted_label  surprise
# Test point  2517  predicted_label  anger
# Test point  2518  predicted_label  anger
# Test point  2519  predicted_label  neutral
# Test point  2520  predicted_label  neutral
# Test point  2521  predicted_label  neutral
# Test point  2522  predicted_label  neutral
# Test point  2523  predicted_label  neutral
# Test point  2524  predicted_label  neutral
# Test point  2525  predicted_label  neutral
# Test point  2526  predicted_label  joy
# Test point  2527  predicted_label  neutral
# Test point  2528  predicted_label  neutral
# Test point  2529  predicted_label  neutral
# Test point  2530  predicted_label  neutral
# Test point  2531  predicted_label  neutral
# Test point  2532  predicted_label  surprise
# Test point  2533  predicted_label  joy
# Test point  2534  predicted_label  neutral
# Test point  2535  predicted_label  neutral
# Test point  2536  predicted_label  neutral
# Test point  2537  predicted_label  neutral
# Test point  2538  predicted_label  neutral
# Test point  2539  predicted_label  neutral
# Test point  2540  predicted_label  surprise
# Test point  2541  predicted_label  neutral
# Test point  2542  predicted_label  neutral
# Test point  2543  predicted_label  neutral
# Test point  2544  predicted_label  neutral
# Test point  2545  predicted_label  neutral
# Test point  2546  predicted_label  neutral
# Test point  2547  predicted_label  neutral
# Test point  2548  predicted_label  surprise
# Test point  2549  predicted_label  anger
# Test point  2550  predicted_label  neutral
# Test point  2551  predicted_label  neutral
# Test point  2552  predicted_label  surprise
# Test point  2553  predicted_label  neutral
# Test point  2554  predicted_label  surprise
# Test point  2555  predicted_label  neutral
# Test point  2556  predicted_label  neutral
# Test point  2557  predicted_label  neutral
# Test point  2558  predicted_label  neutral
# Test point  2559  predicted_label  neutral
# Test point  2560  predicted_label  surprise
# Test point  2561  predicted_label  neutral
# Test point  2562  predicted_label  neutral
# Test point  2563  predicted_label  neutral
# Test point  2564  predicted_label  neutral
# Test point  2565  predicted_label  neutral
# Test point  2566  predicted_label  neutral
# Test point  2567  predicted_label  neutral
# Test point  2568  predicted_label  neutral
# Test point  2569  predicted_label  neutral
# Test point  2570  predicted_label  neutral
# Test point  2571  predicted_label  neutral
# Test point  2572  predicted_label  neutral
# Test point  2573  predicted_label  neutral
# Test point  2574  predicted_label  neutral
# Test point  2575  predicted_label  neutral
# Test point  2576  predicted_label  neutral
# Test point  2577  predicted_label  sadness
# Test point  2578  predicted_label  neutral
# Test point  2579  predicted_label  neutral
# Test point  2580  predicted_label  neutral
# Test point  2581  predicted_label  neutral
# Test point  2582  predicted_label  joy
# Test point  2583  predicted_label  neutral
# Test point  2584  predicted_label  surprise
# Test point  2585  predicted_label  neutral
# Test point  2586  predicted_label  joy
# Test point  2587  predicted_label  neutral
# Test point  2588  predicted_label  neutral
# Test point  2589  predicted_label  neutral
# Test point  2590  predicted_label  neutral
# Test point  2591  predicted_label  joy
# Test point  2592  predicted_label  surprise
# Test point  2593  predicted_label  neutral
# Test point  2594  predicted_label  anger
# Test point  2595  predicted_label  neutral
# Test point  2596  predicted_label  surprise
# Test point  2597  predicted_label  surprise
# Test point  2598  predicted_label  anger
# Test point  2599  predicted_label  neutral
# Test point  2600  predicted_label  neutral
# Test point  2601  predicted_label  neutral
# Test point  2602  predicted_label  neutral
# Test point  2603  predicted_label  neutral
# Test point  2604  predicted_label  neutral
# Test point  2605  predicted_label  neutral
# Test point  2606  predicted_label  neutral
# Test point  2607  predicted_label  neutral
# Test point  2608  predicted_label  neutral
# Test point  2609  predicted_label  neutral
